# %% [markdown]
# # Two standard ways to represent directed and undirected graph
#
# ## 1. adjancency-list (compact for sparse graph where e << v*v)
#
# complexity analysis:
# + space = E + V
# + add edge = 1
# + edge btw v and w = degree(v)
# + iterate over vertices adjacent to v = degree(v)
#
# ## 2. adjacency-matrix
#
# complexity analysis:
# + space = v^2
# + add edge = 1
# + edge btw v and w = 1
# + iterate over vertices adjacent to v = V

# %%
# typical graph api
class Graph:
    def __init__():
        pass
    
    # add edge btw v and w
    def add(v,w):
        pass
    
    # return vertices adjancent to v
    def adj(v):
        pass
    
    # return total number of vertices
    @property
    def V():
        pass
    
    # return total number of edges
    @property
    def E():
        pass
